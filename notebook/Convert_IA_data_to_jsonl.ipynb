# %% [markdown]
# ### Environment Setup
#
# ```
# pip install torch torchvision
# pip install -U spacy
# pip install nltk
# pip install pandas
# pip install numpy
# ```

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/ubuntu/anaconda3/lib/python3.6/site-packages (1.15.4)
# sagemaker 1.18.5 has requirement requests<2.21,>=2.20.0, but you'll have requests 2.21.0 which is incompatible.
# docker-compose 1.23.2 has requirement requests!=2.11.0,!=2.12.2,!=2.18.0,<2.21,>=2.6.1, but you'll have requests 2.21.0 which is incompatible.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import torch
import json
from utils import jsonl
import pandas as pd
import numpy as np
import spacy
import nltk
#nltk.data.path.append("/home/ubuntu/nltk_data") # if nltk_data is downloaded to a customized place

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Checking the Sample Data Provided

# %%
with open('./dataset/stanford-sample/train.jsonl', 'r') as fh:
    stanford_file = fh.readlines()

with open('./dataset/iu-chest/test.jsonl', 'r') as fh:
    iu_file = fh.readlines()

# %%
## return a list, where each item is a parsed dictionary, 
## containing 'part', 'background', 'findings', 'impression' key-value pairs
## 'part' is not required

jsonl.load(stanford_file)
# Out:
# [{'part': 'ankle',
#   'background': ['RADIOGRAPHIC',
#    'EXAMINATION',
#    'OF',
#    'THE',
#    'FOOT',
#    ':',
#    '<DATE>',
#    '<TIME>',
#    'AM',
#    'CLINICAL',
#    'HISTORY',
#    ':',
#    '<AGE>',
#    'years',
#    'of',
#    'age',
#    ',',
#    'Female',
#    ',',
#    'RT',
#    'ANKLE-DXAN2',
#    'DXFT3-WB',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.',
#    'PROCEDURE',
#    'COMMENTS',
#    ':',
#    'Three',
#    'views',
#    'of',
#    'the',
#    'right',
#    'and',
#    'left',
#    'foot',
#    '.',
#    '3',
#    'views',
#    'of',
#    'the',
#    'right',
#    'and',
#    'left',
#    'ankle',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    '3',
#    'views',
#    'of',
#    'the',
#    'left',
#    'foot',
#    'demonstrate',
#    'mild',
#    'midfoot',
#    'degenerative',
#    'changes',
#    'and',
#    'mild',
#    'hammertoe',
#    'deformity',
#    'of',
#    'the',
#    'third',
#    'ray',
#    '.',
#    'No',
#    'acute',
#    'fracture',
#    'or',
#    'dislocation',
#    '.',
#    '3',
#    'views',
#    'of',
#    'the',
#    'right',
#    'foot',
#    'demonstrate',
#    'erosion',
#    'or',
#    'postsurgical',
#    'change',
#    'at',
#    'the',
#    'head',
#    'of',
#    'the',
#    'first',
#    'metatarsal',
#    '.',
#    'Mild',
#    'midfoot',
#    'degenerative',
#    'changes',
#    'are',
#    'seen',
#    'along',
#    'with',
#    'fusion',
#    'at',
#    'the',
#    'proximal',
#    'interphalangeal',
#    'joint',
#    'of',
#    'the',
#    'second',
#    'ray',
#    '.',
#    'This',
#    'may',
#    'be',
#    'postsurgical',
#    'in',
#    'nature',
#    'or',
#    'possibly',
#    'secondary',
#    'to',
#    'an',
#    'inflammatory',
#    'arthropathy',
#    'such',
#    'as',
#    'psoriatic',
#    'arthritis',
#    '.',
#    '3',
#    'views',
#    'of',
#    'the',
#    'right',
#    'ankle',
#    'demonstrate',
#    'widening',
#    'of',
#    'the',
#    'lateral',
#    'ankle',
#    'mortise',
#    'and',
#    'moderate',
#    'degenerative',
#    'changes',
#    'at',
#    'the',
#    'medial',
#    'tibiotalar',
#    'joint',
#    '.',
#    'No',
#    'acute',
#    'fracture',
#    'is',
#    'identified',
#    '3',
#    'views',
#    'of',
#    'the',
#    'left',
#    'ankle',
#    'demonstrate',
#    'minimal',
#    'degenerative',
#    'changes',
#    'mid',
#    'and',
#    'medially',
#    'no',
#    'acute',
#    'fracture',
#    'or',
#    'dislocation'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Likely',
#    'postsurgical',
#    'changes',
#    'in',
#    'the',
#    'right',
#    'foot',
#    '.',
#    'Mild',
#    'hammertoe',
#    'deformity',
#    'of',
#    'the',
#    'left',
#    'third',
#    'ray',
#    '.',
#    'Moderate',
#    'degenerative',
#    'changes',
#    'and',
#    'talar',
#    'tilt',
#    'of',
#    'the',
#    'right',
#    'medial',
#    'ankle',
#    'joint',
#    '.']}]

# %%
jsonl.load(iu_file)
# Out:
# [{'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'status',
#    'post',
#    'XXXX',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Lungs',
#    'are',
#    'clear',
#    'bilaterally',
#    'with',
#    'no',
#    'focal',
#    'infiltrate',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothoraces',
#    '.',
#    'Cardiomediastinal',
#    'silhouette',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'XXXX',
#    'and',
#    'soft',
#    'tissues',
#    'are',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    ',',
#    'post',
#    'XXXX',
#    'closure',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Atrial',
#    'septal',
#    'occluder',
#    'artifact',
#    '.',
#    'Rotated',
#    'frontal',
#    'position',
#    ',',
#    'overall',
#    'heart',
#    'size',
#    'within',
#    'normal',
#    'limits',
#    ',',
#    'no',
#    'typical',
#    'findings',
#    'of',
#    'pulmonary',
#    'edema',
#    '.',
#    'XXXX',
#    'densities',
#    'in',
#    'the',
#    'left',
#    'base',
#    ',',
#    'small',
#    'focal',
#    'XXXX',
#    'opacity',
#    'in',
#    'the',
#    'right',
#    'base',
#    'with',
#    'focal',
#    'posterior',
#    'right',
#    'hemidiaphragm',
#    'elevation',
#    'and',
#    'obscured',
#    'right',
#    'costophrenic',
#    'XXXX',
#    '.',
#    'Biapical',
#    'pleuroparenchymal',
#    'irregularities',
#    'most',
#    'compatible',
#    'with',
#    'scarring',
#    ',',
#    'chronic',
#    'appearing',
#    'right',
#    '5th',
#    'rib',
#    'contour',
#    'deformity',
#    '.',
#    'No',
#    'pneumothorax',
#    'seen',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'XXXX',
#    'densities',
#    'in',
#    'left',
#    'base',
#    'may',
#    'be',
#    'compatible',
#    'with',
#    'scarring',
#    'or',
#    'subsegmental',
#    'atelectasis',
#    'Abnormal',
#    'opacity',
#    'in',
#    'the',
#    'right',
#    'base',
#    'XXXX',
#    'due',
#    'at',
#    'XXXX',
#    'in',
#    'part',
#    'to',
#    'atelectasis',
#    'with',
#    'right',
#    'hemidiaphragm',
#    'eventration',
#    ',',
#    'question',
#    'small',
#    'right',
#    'pleural',
#    'effusion']},
#  {'background': ['INDICATION',
#    ':',
#    'Chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Clear',
#    'lungs',
#    '.',
#    'No',
#    'infiltrates',
#    'or',
#    'suspicious',
#    'pulmonary',
#    'opacity',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'Cardiomediastinal',
#    'silhouette',
#    'within',
#    'normal',
#    'limits',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'with',
#    'osteoarthritis',
#    'of',
#    'the',
#    'left',
#    'hip',
#    '.',
#    'Preop',
#    'evaluation',
#    'for',
#    'hip',
#    'replacement',
#    '.',
#    'COMPARISON',
#    ':',
#    'Two',
#    'views',
#    'of',
#    'the',
#    'chest',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'moderately',
#    'enlarged',
#    '.',
#    'There',
#    'is',
#    'evidence',
#    'of',
#    'previous',
#    'aortic',
#    'valve',
#    'replacement',
#    '.',
#    'XXXX',
#    'sternotomy',
#    'XXXX',
#    'are',
#    'grossly',
#    'intact',
#    '.',
#    'The',
#    'pulmonary',
#    'XXXX',
#    'and',
#    'mediastinum',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'There',
#    'is',
#    'no',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'There',
#    'are',
#    'chronically',
#    'increased',
#    'interstitial',
#    'lung',
#    'markings',
#    'without',
#    'superimposed',
#    'focal',
#    'airspace',
#    'disease',
#    'identified',
#    '.',
#    'There',
#    'are',
#    'degenerative',
#    'changes',
#    'of',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Cardiomegaly',
#    'without',
#    'superimposed',
#    'acute',
#    'disease',
#    'noted',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'woman',
#    'with',
#    'syncopal',
#    'episode',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'lungs',
#    'demonstrate',
#    'low',
#    'lung',
#    'volumes',
#    'but',
#    'are',
#    'clear',
#    'bilaterally',
#    '.',
#    'Specifically',
#    ',',
#    'no',
#    'evidence',
#    'of',
#    'focal',
#    'consolidation',
#    ',',
#    'pneumothorax',
#    ',',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'Mild',
#    'streaky',
#    'opacities',
#    'in',
#    'the',
#    'left',
#    'upper',
#    'lobe',
#    'on',
#    'frontal',
#    'projection',
#    'are',
#    'XXXX',
#    'atelectatic',
#    'or',
#    'scar',
#    '.',
#    'Cardio',
#    'mediastinal',
#    'silhouette',
#    'is',
#    'unremarkable',
#    '.',
#    'Visualized',
#    'osseous',
#    'structures',
#    'of',
#    'the',
#    'thorax',
#    'are',
#    'without',
#    'acute',
#    'abnormality',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    'without',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'with',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'The',
#    'none',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'No',
#    'focal',
#    'consolidation',
#    '.',
#    'No',
#    'visualized',
#    'pneumothorax',
#    '.',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'normal',
#    '.',
#    'No',
#    'large',
#    'pleural',
#    'effusions',
#    '.',
#    'The',
#    'cardiomediastinal',
#    'silhouette',
#    'is',
#    'grossly',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'woman',
#    ',',
#    '8-1/2',
#    'months',
#    'pregnant',
#    ',',
#    'with',
#    'dyspnea',
#    'and',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Cardiomediastinal',
#    'silhouette',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'acute',
#    'bony',
#    'abnormality',
#    'is',
#    'identified',
#    '.',
#    'There',
#    'is',
#    'slightly',
#    'increased',
#    'XXXX',
#    'opacity',
#    'of',
#    'the',
#    'right',
#    'base',
#    'compared',
#    'to',
#    'the',
#    'left',
#    'which',
#    'may',
#    'minimal',
#    'right',
#    'basilar',
#    'airspace',
#    'disease',
#    ',',
#    'XXXX',
#    'in',
#    'the',
#    'right',
#    'middle',
#    'lobe',
#    '.',
#    'The',
#    'left',
#    'lung',
#    'is',
#    'clear',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'effusion',
#    'identified',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Minimal',
#    'right',
#    'basilar',
#    'airspace',
#    'disease',
#    ',',
#    'XXXX',
#    'right',
#    'middle',
#    'lobe',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Right-sided',
#    'chest',
#    'pain',
#    ',',
#    'muscle',
#    'spasms'],
#   'findings': ['FINDINGS',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    '.',
#    'Cardiomediastinal',
#    'silhouette',
#    'and',
#    'pulmonary',
#    'vasculature',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Streaky',
#    'bibasilar',
#    'airspace',
#    'opacities',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'No',
#    'acute',
#    'osseous',
#    'findings',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    'with',
#    'streaky',
#    'bibasilar',
#    'opacities',
#    ',',
#    'XXXX',
#    'subsegmental',
#    'atelectasis',
#    'over',
#    'infiltrate',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    ',',
#    'hypoxia',
#    '.',
#    'COMPARISON',
#    ':',
#    'PA',
#    'lateral',
#    'views',
#    'of',
#    'the',
#    'chest',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Bilateral',
#    'emphysematous',
#    'again',
#    'noted',
#    'and',
#    'lower',
#    'lobe',
#    'fibrotic',
#    'changes',
#    '.',
#    'Postsurgical',
#    'changes',
#    'of',
#    'the',
#    'chest',
#    'including',
#    'CABG',
#    'procedure',
#    ',',
#    'stable',
#    '.',
#    'Stable',
#    'valve',
#    'artifact',
#    '.',
#    'There',
#    'are',
#    'no',
#    'focal',
#    'areas',
#    'of',
#    'consolidation',
#    '.',
#    'No',
#    'large',
#    'pleural',
#    'effusions',
#    '.',
#    'No',
#    'evidence',
#    'of',
#    'pneumothorax',
#    '.',
#    'Degenerative',
#    'changes',
#    'noted',
#    'of',
#    'the',
#    'visualized',
#    'thoracic',
#    'spine',
#    '.',
#    'Nodular',
#    'right',
#    'lower',
#    'lobe',
#    'opacity',
#    ',',
#    'XXXX',
#    'nipple',
#    'XXXX',
#    '.',
#    'Contour',
#    'abnormality',
#    'of',
#    'the',
#    'posterior',
#    'aspect',
#    'of',
#    'the',
#    'right',
#    '7th',
#    'rib',
#    'again',
#    'noted',
#    ',',
#    'stable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.',
#    'Stable',
#    'bilateral',
#    'emphysematous',
#    'and',
#    'lower',
#    'lobe',
#    'fibrotic',
#    'changes',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'examination',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'seen',
#    '.',
#    'Calcified',
#    'lymph',
#    'XXXX',
#    'and',
#    'granuloma',
#    'are',
#    'noted',
#    '.',
#    'Mild',
#    'degenerative',
#    'changes',
#    'are',
#    'present',
#    'in',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'active',
#    'disease',
#    '.']},
#  {'background': ['INDICATION', ':', 'Vomiting', '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'and',
#    'lungs',
#    'have',
#    'XXXX',
#    'XXXX',
#    'in',
#    'the',
#    'interval',
#    '.',
#    'Both',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'acute',
#    'infiltrates',
#    'and',
#    'expanded',
#    '.',
#    'Strandy',
#    'scarring',
#    'in',
#    'the',
#    'left',
#    'lower',
#    'lobe',
#    'is',
#    'unchanged',
#    '.',
#    'Heart',
#    'and',
#    'mediastinum',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'active', 'disease', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'tuberculosis',
#    'positive',
#    'PPD',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'normal',
#    '.',
#    'Lungs',
#    'are',
#    'clear',
#    '.',
#    'XXXX',
#    'are',
#    'normal',
#    '.',
#    'No',
#    'pneumonia',
#    ',',
#    'effusions',
#    ',',
#    'edema',
#    ',',
#    'pneumothorax',
#    ',',
#    'adenopathy',
#    ',',
#    'nodules',
#    'or',
#    'masses',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Normal',
#    'chest',
#    'No',
#    'evidence',
#    'of',
#    'tuberculosis',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Rule',
#    'out',
#    'tuberculosis',
#    ',',
#    'facility',
#    'placement',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Lungs',
#    'are',
#    'clear',
#    'bilaterally',
#    '.',
#    'Cardiac',
#    'and',
#    'mediastinal',
#    'silhouettes',
#    'are',
#    'normal',
#    '.',
#    'Pulmonary',
#    'vasculature',
#    'is',
#    'normal',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'No',
#    'acute',
#    'bony',
#    'abnormality',
#    '.',
#    'The',
#    'distal',
#    'tip',
#    'of',
#    'a',
#    'right',
#    'IJ',
#    'dual-lumen',
#    'central',
#    'venous',
#    'catheter',
#    'is',
#    'at',
#    'the',
#    'XXXX',
#    'which',
#    'junction',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'active',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'with',
#    'weakness',
#    '.',
#    'COMPARISON',
#    ':',
#    'Right',
#    'rib',
#    'films',
#    'from',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'is',
#    'normal',
#    '.',
#    'No',
#    'focal',
#    'consolidations',
#    '.',
#    'There',
#    'are',
#    'degenerative',
#    'changes',
#    'throughout',
#    'the',
#    'midlower',
#    'thoracic',
#    'spine',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Peripheral',
#    'edema',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'XXXX',
#    'examination',
#    'consists',
#    'of',
#    'frontal',
#    'and',
#    'lateral',
#    'radiographs',
#    'of',
#    'the',
#    'chest',
#    '.',
#    'The',
#    'cardiomediastinal',
#    'contours',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Pulmonary',
#    'vascularity',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'There',
#    'is',
#    'a',
#    'vague',
#    'right',
#    'suprahilar',
#    'density',
#    'with',
#    'elevation',
#    'of',
#    'the',
#    'XXXX',
#    'fissure',
#    'most',
#    'XXXX',
#    'mild',
#    'subsegmental',
#    'atelectasis',
#    'though',
#    'superimposed',
#    'infection',
#    'can',
#    'not',
#    'be',
#    'entirely',
#    'excluded',
#    '.',
#    'The',
#    'remaining',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'The',
#    'visualized',
#    'osseous',
#    'structures',
#    'and',
#    'upper',
#    'abdomen',
#    'are',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Right',
#    'upper',
#    'lobe',
#    'subsegmental',
#    'atelectasis',
#    '.',
#    'No',
#    'evidence',
#    'of',
#    'heart',
#    'failure',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Bone',
#    'marrow',
#    'transplant',
#    'evaluation',
#    '.',
#    'AML',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'seen',
#    '.',
#    'PICC',
#    'line',
#    'is',
#    'in',
#    'XXXX',
#    '.',
#    'The',
#    'tip',
#    'is',
#    'in',
#    'the',
#    'upper',
#    'right',
#    'atrium',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'active',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    'with',
#    'XXXX',
#    "'s",
#    'syndrome',
#    'previous',
#    'history',
#    'of',
#    'XXXX',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'Chest',
#    'x-XXXX',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Stable',
#    'appearance',
#    'of',
#    'previous',
#    'XXXX',
#    'sternotomy',
#    '.',
#    'Stable',
#    'cardiomegaly',
#    '.',
#    'Stable',
#    'mild',
#    'bilateral',
#    'interstitial',
#    'opacities',
#    'in',
#    'which',
#    'may',
#    'represent',
#    'mild',
#    'pulmonary',
#    'edema',
#    '.',
#    'No',
#    'evidence',
#    'of',
#    'large',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Stable',
#    'cardiomegaly',
#    'and',
#    'mild',
#    'bilateral',
#    'interstitial',
#    'opacities',
#    'which',
#    'represent',
#    'mild',
#    'pulmonary',
#    'edema',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    ',',
#    'bone',
#    'marrow',
#    'transplant',
#    'workup',
#    '.',
#    'COMPARISON',
#    ':',
#    'Portable',
#    'chest',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Left',
#    'XXXX',
#    'XXXX',
#    'noted',
#    'with',
#    'tip',
#    'approximating',
#    'the',
#    'high',
#    'SVC',
#    ',',
#    'stable',
#    '.',
#    'No',
#    'pleural',
#    'effusions',
#    '.',
#    'No',
#    'pneumothorax',
#    '.',
#    'Heart',
#    'size',
#    'is',
#    'normal',
#    'limits',
#    '.',
#    'Degenerative',
#    'changes',
#    'thoracic',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Back',
#    'pain',
#    'and',
#    'hemoptysis',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'heart',
#    'size',
#    '.',
#    'Clear',
#    'lungs',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'findings', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Syncope',
#    '.',
#    'Chest',
#    'and',
#    'abdominal',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Frontal',
#    'and',
#    'lateral',
#    'views',
#    'of',
#    'the',
#    'chest',
#    'show',
#    'normal',
#    'size',
#    'and',
#    'configuration',
#    'of',
#    'the',
#    'cardiac',
#    'silhouette',
#    '.',
#    'Normal',
#    'pulmonary',
#    'vasculature',
#    'and',
#    'central',
#    'airways',
#    '.',
#    'No',
#    'focal',
#    'airspace',
#    'consolidation',
#    'or',
#    'pleural',
#    'effusion',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'or',
#    'active',
#    'cardiac',
#    ',',
#    'pulmonary',
#    'or',
#    'pleural',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Low',
#    'back',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'noted',
#    '.',
#    'Degenerative',
#    'changes',
#    'are',
#    'noted',
#    'in',
#    'the',
#    'spine',
#    '.',
#    'The',
#    'descending',
#    'thoracic',
#    'aorta',
#    'is',
#    'mildly',
#    'tortuous',
#    '.',
#    'The',
#    'mediastinum',
#    'appears',
#    'somewhat',
#    'prominent',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Prominent',
#    'mediastinum',
#    '.',
#    'May',
#    'be',
#    'due',
#    'to',
#    'mediastinal',
#    'fat',
#    '.',
#    'Comparison',
#    'films',
#    ',',
#    'if',
#    'available',
#    ',',
#    'would',
#    'be',
#    'useful',
#    'to',
#    'determine',
#    'if',
#    'this',
#    'is',
#    'a',
#    'chronic',
#    'appearance',
#    '.',
#    'Clear',
#    'lungs',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    'with',
#    'dyspnea',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'cardiac',
#    'contours',
#    '.',
#    'Clear',
#    'lung',
#    'XXXX',
#    'bilaterally',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusions',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormalities',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Dyspnea',
#    'and',
#    'weakness',
#    'COMPARISON',
#    ':',
#    'None',
#    'available',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'slightly',
#    'upper',
#    'normal',
#    '.',
#    'Atherosclerotic',
#    'calcifications',
#    'within',
#    'the',
#    'aorta',
#    '.',
#    'Lungs',
#    'are',
#    'hyperexpanded',
#    'with',
#    'flattening',
#    'of',
#    'the',
#    'diaphragms',
#    'consistent',
#    'with',
#    'emphysematous',
#    'change',
#    '.',
#    'No',
#    'focal',
#    'airspace',
#    'disease',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'Degenerative',
#    'changes',
#    'of',
#    'the',
#    'spine',
#    'are',
#    'noted',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Emphysematous',
#    'change',
#    'without',
#    'acute',
#    'radiographic',
#    'cardiopulmonary',
#    'process',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Achalasia',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiac',
#    'contours',
#    'are',
#    'normal',
#    '.',
#    'Prior',
#    'granulomatous',
#    'disease',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'Thoracic',
#    'spondylosis',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'process', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'dyspnea',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'A',
#    'strandy',
#    'infiltrate',
#    'has',
#    'developed',
#    'in',
#    'the',
#    'left',
#    'lower',
#    'lobe',
#    '.',
#    'Right',
#    'lung',
#    'is',
#    'clear',
#    '.',
#    'Heart',
#    'size',
#    'remains',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Patchy',
#    'left',
#    'lower',
#    'lobe',
#    'infiltrate',
#    'and',
#    'focal',
#    'atelectasis',
#    ',',
#    'consistent',
#    'with',
#    'pneumonitis',
#    '.']},
#  {'background': [],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'normal',
#    'in',
#    'size',
#    '.',
#    'The',
#    'mediastinum',
#    'is',
#    'unremarkable',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'hypoinflated',
#    '.',
#    'No',
#    'focal',
#    'consolidation',
#    'is',
#    'seen',
#    '.',
#    'Postsurgical/biopsy',
#    'changes',
#    'overlying',
#    'the',
#    'right',
#    'breast',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Mild',
#    'hypoinflation',
#    'without',
#    'acute',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'XXXX',
#    'with',
#    'history',
#    'of',
#    'pneumonia',
#    ',',
#    'persistent',
#    'dyspnea',
#    ',',
#    'HIV-positive',
#    '.',
#    'COMPARISON',
#    ':',
#    'Chest',
#    'x-XXXX',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Negative',
#    'for',
#    'focal',
#    'pulmonary',
#    'consolidation',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'abnormality',
#    '.',
#    'Dextroscoliosis',
#    'of',
#    'thoracic',
#    'spine',
#    'unchanged',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Preprocedure',
#    'evaluation',
#    'prior',
#    'to',
#    'bone',
#    'marrow',
#    'transplant',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'Heart',
#    'and',
#    'pulmonary',
#    'XXXX',
#    'appear',
#    'normal',
#    '.',
#    'The',
#    'pleural',
#    'spaces',
#    'are',
#    'clear',
#    'and',
#    'mediastinal',
#    'contours',
#    'are',
#    'normal',
#    '.',
#    'Nodular',
#    'density',
#    'overlying',
#    'the',
#    'anterior',
#    'left',
#    '4th',
#    'rib',
#    'XXXX',
#    'represents',
#    'a',
#    'healing',
#    'rib',
#    'fracture',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'disease']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'with',
#    'end-stage',
#    'renal',
#    'disease',
#    'on',
#    'hemodialysis',
#    'COMPARISON',
#    ':',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'mildly',
#    'enlarged',
#    '.',
#    'There',
#    'is',
#    'tortuosity',
#    'of',
#    'the',
#    'thoracic',
#    'aorta',
#    '.',
#    'No',
#    'focal',
#    'airspace',
#    'consolidation',
#    ',',
#    'pleural',
#    'effusions',
#    'or',
#    'pneumothorax',
#    '.',
#    'No',
#    'acute',
#    'bony',
#    'abnormalities',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Cardiomegaly',
#    'without',
#    'acute',
#    'pulmonary',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'INDICATION',
#    ':',
#    'HISTORY',
#    'OF',
#    'TOBACCO',
#    'USE',
#    ';',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'lungs',
#    'appear',
#    'clear',
#    '.',
#    'There',
#    'are',
#    'no',
#    'suspicious',
#    'appearing',
#    'pulmonary',
#    'nodules',
#    'or',
#    'masses',
#    '.',
#    'There',
#    'is',
#    'no',
#    'evidence',
#    'of',
#    'pneumonia',
#    '.',
#    'The',
#    'heart',
#    'pulmonary',
#    'XXXX',
#    'appear',
#    'normal',
#    '.',
#    'Pleural',
#    'spaces',
#    'are',
#    'clear',
#    '.',
#    'Mediastinal',
#    'contours',
#    'are',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'disease']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'chest',
#    'pain'],
#   'findings': ['FINDINGS',
#    ':',
#    'Stable',
#    'enlargement',
#    'of',
#    'the',
#    'cardiac',
#    'silhouette',
#    ',',
#    'stable',
#    'mediastinal',
#    'and',
#    'hilar',
#    'contours',
#    ',',
#    'surgical',
#    'clips',
#    'and',
#    'CABG',
#    'markers',
#    '.',
#    'Stable',
#    'XXXX',
#    'densities',
#    'in',
#    'the',
#    'left',
#    'base',
#    'compatible',
#    'with',
#    'scarring',
#    'or',
#    'chronic',
#    'subsegmental',
#    'atelectasis',
#    '.',
#    'No',
#    'focal',
#    'alveolar',
#    'consolidation',
#    ',',
#    'no',
#    'definite',
#    'pleural',
#    'effusion',
#    'seen',
#    '.',
#    'Right',
#    'hilar',
#    'calcifications',
#    'suggest',
#    'a',
#    'previous',
#    'granulomatous',
#    'process',
#    '.',
#    'No',
#    'typical',
#    'findings',
#    'of',
#    'pulmonary',
#    'edema',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'findings']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'woman',
#    'with',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    'available'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'lungs',
#    'are',
#    'hypoventilated',
#    '.',
#    'There',
#    'is',
#    'no',
#    'focal',
#    'consolidation',
#    '.',
#    'Cardiomediastinal',
#    'silhouette',
#    'is',
#    'normal',
#    'in',
#    'size',
#    'and',
#    'contour',
#    '.',
#    'There',
#    'is',
#    'no',
#    'pneumothorax',
#    'or',
#    'large',
#    'pleural',
#    'effusion',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Hypoventilated',
#    'lungs',
#    ',',
#    'but',
#    'no',
#    'focal',
#    'consolidation',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'pain',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'borderline',
#    'enlarged',
#    '.',
#    'No',
#    'focal',
#    'alveolar',
#    'consolidation',
#    ',',
#    'no',
#    'definite',
#    'pleural',
#    'effusion',
#    'seen',
#    '.',
#    'No',
#    'typical',
#    'findings',
#    'of',
#    'pulmonary',
#    'edema',
#    '.',
#    'Dense',
#    'nodule',
#    'in',
#    'the',
#    'right',
#    'lower',
#    'lobe',
#    'suggests',
#    'a',
#    'previous',
#    'granulomatous',
#    'process',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Borderline',
#    'heart',
#    'size',
#    ',',
#    'no',
#    'acute',
#    'pulmonary',
#    'findings']},
#  {'background': ['INDICATION',
#    ':',
#    'dyspnea',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'large',
#    '.',
#    'Lung',
#    'volumes',
#    'are',
#    'XXXX',
#    '.',
#    'XXXX',
#    'opacity',
#    'persists',
#    'in',
#    'the',
#    'right',
#    'midlung',
#    '.',
#    'No',
#    'focal',
#    'infiltrates',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Persistent',
#    'cardiomegaly',
#    '.',
#    'Right',
#    'midlung',
#    'scar',
#    '.',
#    'No',
#    'visible',
#    'acute',
#    'failure',
#    'or',
#    'pneumonia',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Right',
#    'post',
#    'thoracic',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    'available',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'There',
#    'are',
#    'T-spine',
#    'osteophytes',
#    '.',
#    'The',
#    'cardiomediastinal',
#    'silhouette',
#    'and',
#    'pulmonary',
#    'vasculature',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'There',
#    'is',
#    'no',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'There',
#    'are',
#    'no',
#    'focal',
#    'areas',
#    'of',
#    'consolidation',
#    '.',
#    'There',
#    'are',
#    'low',
#    'lung',
#    'volumes',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Lung',
#    'volumes',
#    'with',
#    'streaky',
#    'left',
#    'basilar',
#    'opacity',
#    'consistent',
#    'with',
#    'subsegmental',
#    'atelectasis',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'Chest',
#    'radiographs',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiomediastinal',
#    'silhouette',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    'for',
#    'size',
#    'and',
#    'contour',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'normally',
#    'inflated',
#    'without',
#    'evidence',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'Stable',
#    'calcified',
#    'granuloma',
#    'within',
#    'the',
#    'right',
#    'upper',
#    'lung',
#    '.',
#    'No',
#    'acute',
#    'bone',
#    'abnormality',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'process',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'congestion',
#    '.',
#    'COMPARISON',
#    ':',
#    'PA',
#    'lateral',
#    'views',
#    'of',
#    'the',
#    'chest',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Calcified',
#    'left',
#    'lower',
#    'lobe',
#    'granuloma',
#    '.',
#    'No',
#    'focal',
#    'areas',
#    'of',
#    'consolidation',
#    '.',
#    'No',
#    'pleural',
#    'effusions',
#    '.',
#    'No',
#    'pneumothorax',
#    '.',
#    'Degenerative',
#    'changes',
#    'noted',
#    'of',
#    'the',
#    'thoracic',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION', ':', '53yof', 'pre-op', 'x-XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'normal',
#    'in',
#    'size',
#    '.',
#    'The',
#    'mediastinum',
#    'is',
#    'unremarkable',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'mildly',
#    'hypoinflated',
#    'but',
#    'clear',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'disease', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'XXXX',
#    ',',
#    'difficulty',
#    'breathing',
#    'COMPARISON',
#    ':',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'within',
#    'normal',
#    'limits',
#    ',',
#    'stable',
#    'mediastinal',
#    'and',
#    'hilar',
#    'contours',
#    '.',
#    'No',
#    'alveolar',
#    'consolidation',
#    ',',
#    'no',
#    'findings',
#    'of',
#    'pleural',
#    'effusion',
#    'or',
#    'pulmonary',
#    'edema',
#    '.',
#    'Chronic',
#    'appearing',
#    'contour',
#    'deformity',
#    'of',
#    'the',
#    'right',
#    'posterolateral',
#    '7th',
#    'rib',
#    'again',
#    'noted',
#    'suggestive',
#    'of',
#    'old',
#    'injury',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'findings']},
#  {'background': ['INDICATION',
#    ':',
#    'The',
#    'patient',
#    'is',
#    'a',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    'with',
#    'history',
#    'of',
#    'a',
#    'mild',
#    'PPD',
#    'reaction',
#    ',',
#    'screening',
#    'x-XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    'with',
#    'redemonstrated',
#    'bronchovascular',
#    'crowding',
#    '.',
#    'The',
#    'trachea',
#    'is',
#    'midline',
#    '.',
#    'Negative',
#    'for',
#    'pneumothorax',
#    ',',
#    'pleural',
#    'effusion',
#    'or',
#    'focal',
#    'airspace',
#    'consolidation',
#    '.',
#    'The',
#    'cardiac',
#    'silhouette',
#    'size',
#    'is',
#    'borderline',
#    'enlarged',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Borderline',
#    'enlargement',
#    'of',
#    'cardiac',
#    'silhouette',
#    ',',
#    'otherwise',
#    'no',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.',
#    'No',
#    'evidence',
#    'for',
#    'active',
#    'TB',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'XXXX',
#    'with',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    ',',
#    'mediastinal',
#    'contour',
#    ',',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'are',
#    'similar',
#    'to',
#    'comparison',
#    'exam',
#    'and',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'consolidation',
#    ',',
#    'suspicious',
#    'pulmonary',
#    'opacity',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'The',
#    'visualized',
#    'osseous',
#    'structures',
#    'appear',
#    'intact',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormalities',
#    '.']},
#  {'background': ['INDICATION', ':', 'XXXX', 'COMPARISON', ':', 'None', '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'and',
#    'mediastinal',
#    'contour',
#    'are',
#    'normal',
#    '.',
#    'Pulmonary',
#    'vascularity',
#    'is',
#    'normal',
#    '.',
#    'Lungs',
#    'are',
#    'clear',
#    '.',
#    'No',
#    'pleural',
#    'effusions',
#    'or',
#    'pneumothoraces',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'Normal', 'chest', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'pt',
#    'with',
#    'left',
#    'sided',
#    'chest',
#    'pain',
#    ',',
#    'nonradiating',
#    '.',
#    'Pt',
#    'with',
#    'XXXX',
#    'XXXX',
#    'smoking',
#    'histo',
#    'COMPARISON',
#    ':',
#    'in',
#    'XXXX',
#    ',',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Prominent',
#    'interstitial',
#    'markings',
#    'in',
#    'the',
#    'lungs',
#    'are',
#    'unchanged',
#    '.',
#    'No',
#    'focal',
#    'infiltrates',
#    '.',
#    'Heart',
#    'and',
#    'pulmonary',
#    'XXXX',
#    'are',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Chronic',
#    'interstitial',
#    'lung',
#    'disease',
#    'and',
#    'scars',
#    'unchanged',
#    '.',
#    'No',
#    'acute',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'GERM',
#    'CELL',
#    'TUMOR',
#    'BMT',
#    'W/U',
#    'LAB',
#    ';',
#    'COMPARISON',
#    ':',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'normal',
#    'in',
#    'size',
#    '.',
#    'The',
#    'mediastinum',
#    'is',
#    'unremarkable',
#    '.',
#    'The',
#    'chest',
#    'XXXX',
#    'is',
#    'in',
#    'satisfactory',
#    'position',
#    '.',
#    'There',
#    'is',
#    'no',
#    'pneumothorax',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'disease', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Exertional',
#    'chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'None',
#    'available'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiac',
#    'silhouette',
#    'pulmonary',
#    'vascularity',
#    'are',
#    'normal',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'There',
#    'is',
#    'no',
#    'evidence',
#    'of',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'Mild',
#    'degenerative',
#    'changes',
#    'are',
#    'present',
#    'in',
#    'the',
#    'XXXX',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'acute',
#    'cardiopulmonary',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'seen',
#    '.',
#    'Scoliosis',
#    'and',
#    'degenerative',
#    'changes',
#    'are',
#    'present',
#    'in',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'active',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'status',
#    'post',
#    'pyeloplasty',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    'available',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    ',',
#    'mediastinal',
#    'contour',
#    ',',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'consolidation',
#    ',',
#    'suspicious',
#    'pulmonary',
#    'opacity',
#    ',',
#    'large',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    'is',
#    'identified',
#    '.',
#    'Visualized',
#    'osseous',
#    'structures',
#    'appear',
#    'intact',
#    '.',
#    'Surgical',
#    'XXXX',
#    'is',
#    'noted',
#    'in',
#    'the',
#    'right',
#    'upper',
#    'quadrant',
#    '.',
#    'Subcutaneous',
#    'emphysema',
#    'seen',
#    'along',
#    'the',
#    'neck',
#    'bilaterally',
#    ',',
#    'right',
#    'lateral',
#    'upper',
#    'abdomen',
#    ',',
#    'and',
#    'left',
#    'chest',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.',
#    'Subcutaneous',
#    'emphysema',
#    'of',
#    'the',
#    'neck',
#    ',',
#    'left',
#    'lateral',
#    'chest',
#    ',',
#    'and',
#    'right',
#    'lateral',
#    'abdominal',
#    'soft',
#    'tissues',
#    'noted',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Shortness',
#    'of',
#    'breath',
#    'COMPARISON',
#    ':',
#    'PA',
#    'and',
#    'lateral',
#    'chest',
#    'x-XXXX',
#    'dated',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'There',
#    'is',
#    'a',
#    'large',
#    'airspace',
#    'opacity',
#    'in',
#    'the',
#    'right',
#    'lower',
#    'and',
#    'middle',
#    'lobes',
#    '.',
#    'There',
#    'is',
#    'no',
#    'pneumothorax',
#    '.',
#    'Heart',
#    'size',
#    'is',
#    'normal',
#    '.',
#    'Soft',
#    'tissue',
#    'and',
#    'bony',
#    'structures',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Multilobar',
#    'airspace',
#    'consolidation',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'and',
#    'congestion',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    '.',
#    'Heart',
#    'size',
#    'and',
#    'mediastinal',
#    'contour',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'air',
#    'space',
#    'consolidation',
#    ',',
#    'pneumothorax',
#    ',',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'Mild',
#    'thoracic',
#    'spine',
#    'degenerative',
#    'change',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'with',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'PA',
#    'and',
#    'lateral',
#    'chest',
#    'x-XXXX',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'normal',
#    '.',
#    'The',
#    'mediastinal',
#    'contour',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'any',
#    'focal',
#    'infiltrates',
#    '.',
#    'There',
#    'is',
#    'redemonstration',
#    'of',
#    'a',
#    'calcified',
#    'granuloma',
#    'within',
#    'the',
#    'left',
#    'upper',
#    'lobe',
#    '.',
#    'There',
#    'are',
#    'no',
#    'nodules',
#    'or',
#    'masses',
#    '.',
#    'No',
#    'visible',
#    'pneumothorax',
#    '.',
#    'No',
#    'visible',
#    'pleural',
#    'fluid',
#    '.',
#    'The',
#    'XXXX',
#    'are',
#    'grossly',
#    'normal',
#    '.',
#    'There',
#    'is',
#    'no',
#    'visible',
#    'free',
#    'intraperitoneal',
#    'air',
#    'under',
#    'the',
#    'diaphragm',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'radiographic',
#    'cardiopulmonary',
#    'process',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    ',',
#    'chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'There',
#    'are',
#    'scattered',
#    'XXXX',
#    'opacities',
#    'in',
#    'the',
#    'left',
#    'lower',
#    'lobe',
#    '.',
#    'Cardiac',
#    'silhouette',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'There',
#    'is',
#    'prominence',
#    'of',
#    'the',
#    'right',
#    'and',
#    'left',
#    'hilum',
#    'XXXX',
#    'representing',
#    'enlargement',
#    'of',
#    'the',
#    'central',
#    'pulmonary',
#    'arteries',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'No',
#    'acute',
#    'bone',
#    'abnormality',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Left',
#    'lower',
#    'lobe',
#    'opacities',
#    'XXXX',
#    'representing',
#    'pneumonia',
#    '.',
#    'Enlargement',
#    'of',
#    'the',
#    'central',
#    'pulmonary',
#    'arteries',
#    'raising',
#    'the',
#    'question',
#    'of',
#    'pulmonary',
#    'hypertension',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'medicine',
#    'screening',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Lungs',
#    'are',
#    'clear',
#    'bilaterally',
#    '.',
#    'There',
#    'is',
#    'no',
#    'focal',
#    'consolidation',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothoraces',
#    '.',
#    'There',
#    'is',
#    'widening',
#    'adjacent',
#    'to',
#    'the',
#    'right',
#    'paratracheal',
#    'stripe',
#    ',',
#    'most',
#    'XXXX',
#    'represents',
#    'the',
#    'SVC',
#    'with',
#    'rotated',
#    'position',
#    '.',
#    'XXXX',
#    'are',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'with',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'heart',
#    'size',
#    '.',
#    'Clear',
#    'lungs',
#    '.',
#    'No',
#    'pneumothorax',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    '.',
#    'There',
#    'is',
#    'opacity',
#    'at',
#    'the',
#    'base',
#    'of',
#    'the',
#    'mediastinum',
#    'which',
#    'is',
#    'XXXX',
#    'a',
#    'hiatal',
#    'hernia',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Ovarian',
#    'carcinoma',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    'are',
#    'present',
#    '.',
#    'The',
#    'heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'seen',
#    '.',
#    'Scattered',
#    'XXXX',
#    'of',
#    'left',
#    'base',
#    'atelectasis',
#    'are',
#    'noted',
#    '.',
#    'Left',
#    'XXXX-a-XXXX',
#    'is',
#    'in',
#    'XXXX',
#    'with',
#    'the',
#    'tip',
#    'projecting',
#    'over',
#    'the',
#    'caval',
#    'atrial',
#    'junction',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'XXXX',
#    'of',
#    'left',
#    'base',
#    'atelectasis',
#    '.',
#    'Otherwise',
#    ',',
#    'clear',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'XXXX',
#    'with',
#    'XXXX',
#    ',',
#    'productive',
#    'XXXX',
#    ',',
#    'XXXX',
#    'for',
#    'nodule',
#    'or',
#    'TB',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    'available'],
#   'findings': ['FINDINGS',
#    ':',
#    'Cardiac',
#    'and',
#    'mediastinal',
#    'contours',
#    'are',
#    'unremarkable',
#    '.',
#    'Pulmonary',
#    'vascularity',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'air',
#    'space',
#    'opacities',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'XXXX',
#    'are',
#    'grossly',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'Clear', 'lungs', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    'with',
#    'history',
#    'of',
#    'seizure',
#    '.',
#    'COMPARISON',
#    ':',
#    'AP',
#    'portable',
#    'chest',
#    'x-XXXX',
#    'dated',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Heart',
#    'size',
#    'is',
#    'enlarged',
#    '.',
#    'The',
#    'aorta',
#    'is',
#    'unfolded',
#    '.',
#    'Otherwise',
#    'the',
#    'mediastinal',
#    'contour',
#    'is',
#    'normal',
#    '.',
#    'There',
#    'are',
#    'streaky',
#    'bibasilar',
#    'opacities',
#    '.',
#    'There',
#    'are',
#    'no',
#    'nodules',
#    'or',
#    'masses',
#    '.',
#    'No',
#    'visible',
#    'pneumothorax',
#    '.',
#    'No',
#    'visible',
#    'pleural',
#    'fluid',
#    '.',
#    'The',
#    'XXXX',
#    'are',
#    'grossly',
#    'normal',
#    '.',
#    'There',
#    'is',
#    'no',
#    'visible',
#    'free',
#    'intraperitoneal',
#    'air',
#    'under',
#    'the',
#    'diaphragm',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Cardiomegaly',
#    'with',
#    'mild',
#    'bibasilar',
#    'infiltrates',
#    'versus',
#    'atelectasis',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'cig',
#    'XXXX',
#    'and',
#    'wt',
#    'loss',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Three',
#    'noncalcified',
#    'lung',
#    'nodules',
#    'are',
#    'present',
#    'in',
#    'the',
#    'left',
#    'lower',
#    'lobe',
#    '.',
#    'The',
#    'largest',
#    'measures',
#    '3.5',
#    'mm',
#    'in',
#    'diameter',
#    '.',
#    'Another',
#    'nodule',
#    'is',
#    'present',
#    'near',
#    'the',
#    'right',
#    'hilum',
#    '.',
#    'It',
#    'is',
#    'approximately',
#    '2',
#    'cm',
#    'in',
#    'diameter',
#    '.',
#    'The',
#    'XXXX',
#    'and',
#    'mediastinum',
#    'appear',
#    'normal',
#    '.',
#    'Heart',
#    'size',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Multiple',
#    'nodules',
#    'in',
#    'both',
#    'the',
#    'left',
#    'and',
#    'right',
#    'lungs',
#    'consistent',
#    'with',
#    'neoplasm',
#    '.',
#    'Further',
#    'workup',
#    'could',
#    'be',
#    'initiated',
#    'with',
#    'contrasted',
#    'CT',
#    'of',
#    'the',
#    'chest',
#    ',',
#    'abdomen',
#    ',',
#    'and',
#    'pelvis',
#    '.',
#    'Dr.',
#    'XXXX',
#    'XXXX',
#    'I',
#    'discussed',
#    'the',
#    'findings',
#    'and',
#    'further',
#    'workup',
#    'suggestions',
#    'by',
#    'telephone',
#    'approximately',
#    'XXXX',
#    'hours',
#    'XXXX',
#    ',',
#    'XXXX',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'with',
#    'XXXX',
#    'for',
#    '3',
#    'weeks',
#    '.',
#    'Possible',
#    'pneumonia',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'There',
#    'are',
#    'minimal',
#    'XXXX',
#    'left',
#    'basilar',
#    'opacities',
#    ',',
#    'XXXX',
#    'subsegmental',
#    'atelectasis',
#    'or',
#    'scarring',
#    '.',
#    'There',
#    'is',
#    'no',
#    'focal',
#    'airspace',
#    'consolidation',
#    'to',
#    'suggest',
#    'pneumonia',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'Heart',
#    'size',
#    'is',
#    'at',
#    'the',
#    'upper',
#    'limits',
#    'of',
#    'normal',
#    '.',
#    'Cardiac',
#    'defibrillator',
#    'XXXX',
#    'overlies',
#    'the',
#    'right',
#    'ventricle',
#    '.',
#    'The',
#    'XXXX',
#    'appears',
#    'intact',
#    '.',
#    'There',
#    'is',
#    'aortic',
#    'atherosclerotic',
#    'vascular',
#    'calcification',
#    '.',
#    'Calcified',
#    'mediastinal',
#    'and',
#    'hilar',
#    'lymph',
#    'XXXX',
#    'are',
#    'consistent',
#    'with',
#    'prior',
#    'granulomatous',
#    'disease',
#    '.',
#    'Multiple',
#    'calcified',
#    'splenic',
#    'granulomas',
#    'are',
#    'also',
#    'noted',
#    '.',
#    'There',
#    'are',
#    'minimal',
#    'degenerative',
# ...
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'is',
#    'at',
#    'the',
#    'upper',
#    'limits',
#    'of',
#    'normal',
#    'in',
#    'size',
#    '.',
#    'The',
#    'pulmonary',
#    'vascularity',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    'in',
#    'appearance',
#    '.',
#    'No',
#    'focal',
#    'air',
#    'space',
#    'opacities',
#    '.',
#    'No',
#    'pleural',
#    'effusions',
#    'or',
#    'pneumothorax',
#    '.',
#    'No',
#    'acute',
#    'bony',
#    'abnormalities',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormalities',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Mediastinal',
#    'contours',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Heart',
#    'size',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'consolidation',
#    ',',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'Cervical',
#    'fusion',
#    'XXXX',
#    '.',
#    'Degenerative',
#    'changes',
#    'of',
#    'the',
#    'spine',
#    'and',
#    'the',
#    'acromioclavicular',
#    'joints',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    'with',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'Chest',
#    'radiograph',
#    'XXXX/XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'cardiac',
#    'contour',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'Clear',
#    'lungs',
#    'bilaterally',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormalities',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    '.',
#    'Chest',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiomediastinal',
#    'silhouette',
#    'is',
#    'normal',
#    'in',
#    'size',
#    'and',
#    'contour',
#    '.',
#    'No',
#    'focal',
#    'consolidation',
#    ',',
#    'pneumothorax',
#    'or',
#    'large',
#    'pleural',
#    'effusion',
#    '.',
#    'Suspected',
#    'XXXX',
#    'artifact',
#    'over',
#    'the',
#    'bilateral',
#    'neck',
#    'soft',
#    'tissues',
#    'and',
#    'supraclavicular',
#    'fossae',
#    '.',
#    'Normal',
#    'XXXX',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Negative',
#    'for',
#    'acute',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION', ':', 'dyspnea', 'COMPARISON', ':', 'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Hyperexpanded',
#    'lungs',
#    'suggesting',
#    'obstructive',
#    'lung',
#    'disease',
#    '.',
#    'Sequelae',
#    'of',
#    'old',
#    'granulomatous',
#    'disease',
#    '.',
#    'No',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusions',
#    'or',
#    'pneumothoraces',
#    '.',
#    'Heart',
#    'and',
#    'mediastinum',
#    'of',
#    'normal',
#    'size',
#    'and',
#    'contour',
#    '.',
#    'Degenerative',
#    'changes',
#    'in',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Hyperexpanded',
#    'but',
#    'clear',
#    'lungs',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    ',',
#    'dyspnea',
#    'COMPARISON',
#    ':',
#    'None',
#    'available'],
#   'findings': ['FINDINGS',
#    ':',
#    'Mild',
#    'cardiomegaly',
#    '.',
#    'Mild',
#    'unfolding',
#    'of',
#    'the',
#    'thoracic',
#    'aorta',
#    '.',
#    'No',
#    'focal',
#    'air',
#    'space',
#    'opacity',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    '.',
#    'Visualized',
#    'osseous',
#    'structures',
#    'are',
#    'unremarkable',
#    'in',
#    'appearance',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Mild',
#    'cardiomegaly',
#    '.',
#    'Otherwise',
#    ',',
#    'no',
#    'acute',
#    'cardiopulmonary',
#    'abnormalities',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'PA',
#    'and',
#    'lateral',
#    'views',
#    'the',
#    'chest',
#    'were',
#    'obtained',
#    '.',
#    'Heart',
#    'size',
#    'is',
#    'upper',
#    'limits',
#    'normal',
#    'or',
#    'mildly',
#    'enlarged',
#    '.',
#    'The',
#    'thoracic',
#    'aorta',
#    'is',
#    'mildly',
#    'tortuous',
#    '.',
#    'Pulmonary',
#    'XXXX',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'pneumothorax',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'focal',
#    'air',
#    'space',
#    'consolidation',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'with',
#    'chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'None',
#    'available'],
#   'findings': ['FINDINGS',
#    ':',
#    'Low',
#    'lung',
#    'volumes',
#    '.',
#    'Cardiac',
#    'and',
#    'mediastinal',
#    'contours',
#    'are',
#    'unremarkable',
#    '.',
#    'Pulmonary',
#    'vascularity',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'No',
#    'focal',
#    'air',
#    'space',
#    'opacities',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'Mild',
#    'left',
#    'lingular',
#    'platelike',
#    'atelectasis',
#    '.',
#    'XXXX',
#    'are',
#    'grossly',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'disease',
#    '.',
#    'Clear',
#    'lungs',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'The',
#    'patient',
#    'is',
#    'a',
#    'XXXX',
#    'year',
#    'old',
#    'male',
#    'admitted',
#    'for',
#    'ureteral',
#    'calculi',
#    ',',
#    'renal',
#    'calculi',
#    '.',
#    'Examination',
#    'to',
#    'assess',
#    'line',
#    'position',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Right',
#    'subclavian',
#    'catheter',
#    ',',
#    'distal',
#    'tip',
#    'posterior',
#    'to',
#    'the',
#    'head',
#    'of',
#    'the',
#    'clavicle',
#    ',',
#    'the',
#    'level',
#    'of',
#    'the',
#    'subclavian',
#    'vein',
#    '.',
#    'Low',
#    'lung',
#    'volumes',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    '.',
#    'Left',
#    'lower',
#    'lobe',
#    'airspace',
#    'disease',
#    ',',
#    'XXXX',
#    'atelectasis',
#    '.',
#    'Cardiomediastinal',
#    'size',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Pulmonary',
#    'vasculature',
#    'is',
#    'normal',
#    '.',
#    'XXXX',
#    'XXXX',
#    'intact',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Right',
#    'subclavian',
#    'catheter',
#    ',',
#    'distal',
#    'tip',
#    'in',
#    'the',
#    'region',
#    'of',
#    'the',
#    'subclavian',
#    'vein',
#    'at',
#    'the',
#    'level',
#    'of',
#    'clavicular',
#    'head',
#    '.',
#    'Low',
#    'lung',
#    'volumes',
#    ',',
#    'with',
#    'left',
#    'lower',
#    'lung',
#    'atelectasis',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Abdominal',
#    'pain',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'heart',
#    'size',
#    'and',
#    'mediastinal',
#    'contours',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'any',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'In',
#    'the',
#    'left',
#    'lung',
#    'base',
#    ',',
#    'there',
#    'is',
#    'a',
#    '9',
#    'mm',
#    'nodule',
#    'that',
#    'not',
#    'definitively',
#    'calcified',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'No',
#    'acute',
#    'bony',
#    'abnormalities',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'process',
#    '.',
#    '9',
#    'mm',
#    'left',
#    'lower',
#    'lobe',
#    'pulmonary',
#    'nodule',
#    'not',
#    'definitively',
#    'calcified',
#    '.',
#    'Recommend',
#    'comparison',
#    'with',
#    'prior',
#    'images',
#    'to',
#    'document',
#    'stability',
#    '.',
#    'If',
#    'none',
#    'are',
#    'available',
#    'consider',
#    'nonemergent',
#    'XXXX',
#    'chest',
#    'for',
#    'further',
#    'characterization',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiac',
#    'contours',
#    'are',
#    'normal',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'Thoracic',
#    'spondylosis',
#    '.',
#    'XXXX',
#    'XXXX',
#    'of',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'process', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'female',
#    ',',
#    'preop',
#    'COMPARISON',
#    ':',
#    'Chest',
#    'CT',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Normal',
#    'heart',
#    'size',
#    'and',
#    'mediastinal',
#    'contours',
#    '.',
#    'No',
#    'focal',
#    'airspace',
#    'consolidation',
#    '.',
#    'No',
#    'pneumothorax',
#    'or',
#    'pleural',
#    'effusion',
#    '.',
#    'Mild',
#    'dextro',
#    'curvature',
#    'of',
#    'the',
#    'lower',
#    'thoracic',
#    'spine',
#    ',',
#    'this',
#    'may',
#    'be',
#    'positional',
#    '.',
#    'Visualized',
#    'bony',
#    'structures',
#    'are',
#    'otherwise',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'is',
#    'normal',
#    'in',
#    'size',
#    '.',
#    'The',
#    'mediastinum',
#    'is',
#    'unremarkable',
#    '.',
#    'Mild',
#    'pectus',
#    'excavatum',
#    'deformity',
#    'is',
#    'noted',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'disease', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'trachea',
#    'is',
#    'midline',
#    '.',
#    'The',
#    'cardiomediastinal',
#    'silhouette',
#    'is',
#    'normal',
#    '.',
#    'Lung',
#    'XXXX',
#    'are',
#    'clear',
#    'without',
#    'evidence',
#    'of',
#    'effusion',
#    ',',
#    'infiltrate',
#    ',',
#    'or',
#    'pneumothorax',
#    '.',
#    'Visualized',
#    'bony',
#    'structures',
#    'are',
#    'intact',
#    '.',
#    'Visualized',
#    'soft',
#    'tissues',
#    'appear',
#    'normal',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'Normal', 'chest', 'x-XXXX', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Preop',
#    'bariatric',
#    'surgery',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'cardiac',
#    'contours',
#    'are',
#    'normal',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'Thoracic',
#    'spondylosis',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'preoperative',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Kicked',
#    'by',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'Cardiac',
#    'and',
#    'mediastinal',
#    'contours',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Prior',
#    'granulomatous',
#    'disease',
#    '.',
#    'Elevated',
#    'right',
#    'diaphragm',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'XXXX',
#    'degenerative',
#    'spondylosis',
#    '.',
#    'There',
#    'appears',
#    'to',
#    'be',
#    'a',
#    'mildly',
#    'displaced',
#    'fracture',
#    'of',
#    'the',
#    'mid',
#    'right',
#    'clavicle',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Mildly',
#    'displaced',
#    'fracture',
#    'of',
#    'the',
#    'mid',
#    'right',
#    'clavicle',
#    '.',
#    'No',
#    'acute',
#    'pulmonary',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'History',
#    'of',
#    'esophageal',
#    'carcinoma',
#    '.',
#    'Pre-op',
#    'evaluation',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'heart',
#    'size',
#    'and',
#    'pulmonary',
#    'vascularity',
#    'appear',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'free',
#    'of',
#    'focal',
#    'airspace',
#    'disease',
#    '.',
#    'No',
#    'pleural',
#    'effusion',
#    'or',
#    'pneumothorax',
#    'is',
#    'seen',
#    '.',
#    'Calcified',
#    'granuloma',
#    'are',
#    'present',
#    '.',
#    'Degenerative',
#    'changes',
#    'are',
#    'present',
#    'in',
#    'the',
#    'spine',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'evidence',
#    'of',
#    'active',
#    'disease',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    'year',
#    'old',
#    'with',
#    'shortness',
#    'of',
#    'breath',
#    '.',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'No',
#    'focal',
#    'consolidation',
#    '.',
#    'No',
#    'visualized',
#    'pneumothorax',
#    '.',
#    'The',
#    'heart',
#    'size',
#    'is',
#    'normal',
#    '.',
#    'There',
#    'are',
#    'no',
#    'large',
#    'pleural',
#    'effusions',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'findings',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Chest',
#    'pain',
#    'COMPARISON',
#    ':',
#    'None'],
#   'findings': ['FINDINGS',
#    ':',
#    'Lungs',
#    'are',
#    'clear',
#    'bilaterally.There',
#    'is',
#    'no',
#    'focal',
#    'consolidation',
#    ',',
#    'pleural',
#    'effusion',
#    ',',
#    'or',
#    'pneumothoraces',
#    '.',
#    'Cardiomediastinal',
#    'silhouette',
#    'is',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'XXXX',
#    'are',
#    'unremarkable',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'No',
#    'acute',
#    'cardiopulmonary',
#    'abnormality',
#    '.']},
#  {'background': ['INDICATION',
#    ':',
#    'XXXX',
#    '.',
#    'COMPARISON',
#    ':',
#    'XXXX',
#    ',',
#    'XXXX'],
#   'findings': ['FINDINGS',
#    ':',
#    'Cardiac',
#    'and',
#    'mediastinal',
#    'contours',
#    'are',
#    'within',
#    'normal',
#    'limits',
#    '.',
#    'Prior',
#    'granulomatous',
#    'disease',
#    '.',
#    'The',
#    'lungs',
#    'are',
#    'clear',
#    '.',
#    'Bony',
#    'structures',
#    'are',
#    'intact',
#    '.'],
#   'impression': ['IMPRESSION', ':', 'No', 'acute', 'findings', '.']},
#  {'background': ['INDICATION',
#    ':',
#    'Slurred',
#    'speech',
#    ',',
#    'confusion',
#    ',',
#    'weakness',
#    ',',
#    'shortness',
#    'of',
#    'breath',
#    '.',
#    'COMPARISON',
#    ':',
#    'None',
#    '.'],
#   'findings': ['FINDINGS',
#    ':',
#    'The',
#    'XXXX',
#    'examination',
#    'consists',
#    'of',
#    'frontal',
#    'and',
#    'lateral',
#    'radiographs',
#    'of',
#    'the',
#    'chest',
#    '.',
#    'The',
#    'cardiac',
#    'silhouette',
#    'is',
#    'moderately',
#    'enlarged',
#    'with',
#    'a',
#    'cardiothoracic',
#    'ratio',
#    'of',
#    '16.2',
#    '/',
#    '24.7',
#    '.',
#    'Diffuse',
#    'coarse',
#    'interstitial',
#    'opacity',
#    'seen',
#    'throughout',
#    'the',
#    'lungs',
#    'with',
#    'perihilar',
#    'and',
#    'lower',
#    'lobe',
#    'predominance',
#    '.',
#    'There',
#    'is',
#    'right',
#    'greater',
#    'than',
#    'left',
#    'bibasilar',
#    'consolidation',
#    '.',
#    'There',
#    'are',
#    'small',
#    'pleural',
#    'effusions',
#    ',',
#    'right',
#    'larger',
#    'than',
#    'left',
#    '.',
#    'No',
#    'evidence',
#    'of',
#    'pneumothorax',
#    '.',
#    'Dense',
#    'atherosclerotic',
#    'calcification',
#    'seen',
#    'involving',
#    'the',
#    'thoracic',
#    'and',
#    'upper',
#    'abdominal',
#    'aorta',
#    '.'],
#   'impression': ['IMPRESSION',
#    ':',
#    'Enlarged',
#    'cardiac',
#    'silhouette',
#    'with',
#    'coarse',
#    'perihilar',
#    'and',
#    'lower',
#    'lobe',
#    'interstitial',
#    'opacities',
#    'may',
#    'be',
#    'due',
#    'to',
#    'diffuse',
#    'infection',
#    'or',
#    'heart',
#    'failure',
#    '.',
#    'Small',
#    'pleural',
#    'effusions',
#    '.']},
#  ...]

# %% [markdown]
# ## IA to jsonl Conversion
# - Dingchao has a `all_data_cleaned.csv`, which contains cleaned up raw data, ask him where it is stored

# %%
## IA parsing function

keywords = {'CLINICAL INFORMATION:',
             'COMPARISON:',
             'FINDINGS:',
             'IMPRESSION:',
             'TECHNIQUE:'}

def parse_text(txt, keywords):
    '''separate bulk text into different subparts based on the keywords'''
    
    txt = txt.replace("\t", "")
    txt = re.sub(' +', ' ', txt).strip()
    txt = re.sub('\n+' , '\n', txt)
    txt = re.sub('FINDINGS:( |\n)*' , 'FINDINGS:', txt)
    txt = re.sub('IMPRESSION:( |\n)*' , 'IMPRESSION:', txt)
    
    parts_idx = pd.Series()    
    for keyword in keywords:
        parts_idx[keyword] = txt.find(keyword)
    parts_idx = parts_idx.sort_values()

    result = pd.DataFrame(data=[[""]*len(keywords)], columns=keywords)
    for i in range(len(keywords)):
        keyword = parts_idx.index[i]
        
        if i+1 >= len(keywords):
            result[keyword] = txt[parts_idx.iloc[i]:]
        else:
            result[keyword] = txt[parts_idx.iloc[i]:parts_idx.iloc[i+1]]
    
    result.columns = [col.strip(':') for col in result.columns]
    
    return result

# %%
## IA data to jsonl format

column2jsonKey_mapping = {'TECHNIQUE': 'techinque',
                            'CLINICAL INFORMATION': 'background',
                            'COMPARISON': 'comparison',
                            'FINDINGS': 'findings', 
                            'IMPRESSION': 'impression',
                           }

def tokenize(txt): 
    '''
    Return a list of tokens from txt.
    Can swap in different tokenizers (remove punct, stemming, normalizing, etc.)
    '''
    # spacy is too slow (doing too many other things)
    # nlp = spacy.load('en_core_web_sm')
    # [token.text for token in nlp(row[input_key])]
    txt = txt.lower()
    return nltk.word_tokenize(txt)


def row2json_dict(row, column2jsonKey_mapping, is_tokenized=False):
    json_dict = {}
    for input_key, output_key in column2jsonKey_mapping.items():
        if is_tokenized:
            json_dict[output_key] = row[input_key]
        else:
            json_dict[output_key] = tokenize(row[input_key])
    
    return json_dict


def convert_data_to_jsonl(df):
    
    df  = df.fillna('')
    res = df.apply(lambda row: row2json_dict(row, column2jsonKey_mapping), axis=1)
    
    return res


def dump(data, output_file):
    '''
    Input data is a list of dictionaries. Each list item is one document
    '''
    with open(output_file, 'w') as fh:
        for d in data:
            fh.write(json.dumps(d, ensure_ascii=False)+'\n')
    
    return


def train_test_split(data, train_ratio, dev_ratio, test_ratio):
    '''
    Input data is a list of observations
    '''
    assert train_ratio + dev_ratio + test_ratio == 1.0
    
    total_size = len(data)
    perm_idx = np.random.permutation(total_size)
    data  = np.array(data)[perm_idx].tolist()
    
    train_size = int(total_size * train_ratio)
    dev_size   = int(total_size * dev_ratio)
    test_size  = int(total_size * test_ratio)
    
    train = data[:train_size]
    dev   = data[train_size:(train_size+dev_size)]
    test  = data[-test_size:-1]
    
    return train, dev, test

# %%
data_df = pd.read_csv('./dataset/ia-patients/ull_data_cleaned.csv', header = 0)#, nrows=5000)

# %%
data_df.head(30)
# Out:
#                                            IMPRESSION  \
# 0   Inflammatory changes involving the maxillary, ...
# 1   No significant change from previous with no ev...
# 2                                    Normal brain CT.
# 3                   Normal noncontrast CT scan brain.
# 4   Small vessel ischemic disease with no evidence...
# 5   Status post shunt placement with decreased siz...
# 6   Hemorrhage and increased edema within the left...
# 7   Normal brain CT. if clinical suspicion of isch...
# 8   Normal brain CT. if clinical suspicion for acu...
# 9   No definite evidence of acute cortical ischemi...
# 10                                   Normal brain CT.
# 11  No hydronephrosis. Small left pelvic calcifica...
# 12  Focal inflammation involving colon and pericol...
# 13  Satisfactory appearance of stent graft. Large ...
# 14  1. No definite or gross PE with limitations no...
# 15  1. Lung findings compatible with mild to moder...
# 16  1. No evidence to suggest pulmonary bolus. The...
# 17  Incomplete obstruction, presumably in the regi...
# 18  No evidence of a pulmonary bolus and post sick...
# 19  Interval improvement fluid collections as note...
# 20  No evidence to suggest pulmonary embolus. Smal...
# 21  Infiltrative change in the right lower quadran...
# 22  Wall thickening involving a descending, transv...
# 23  No findings to explain the patient's current s...
# 24  New fluid in the abdomen and pelvis with a flu...
# 25  Left renal cysts. Grossly enlarged prostate.Ab...
# 26                                   Normal brain CT.
# 27  1. Asymmetric patchy area of hypoattenuation i...
# 28  Parenchymal volume loss and small vessel ische...
# 29                                   Normal brain CT.
#
#                                             TECHNIQUE          COMPARISON  \
# 0             Contrast enhanced CT scan of the orbits               None.
# 1      Routine non-contrast examination of the brain.          12/30/2007
# 2      Routine non-contrast examination of the brain.                None
# 3                   Routine noncontrast CT scan brain           9/26/2005
# 4      Routine non-contrast examination of the brain.                None
# 5                   Routine noncontrast CT scan brain  12/31/2007 at 5:18
# 6      Routine non-contrast examination of the brain.          12/29/2007
# 7      Routine non-contrast examination of the brain.                None
# 8      Routine non-contrast examination of the brain.          12/14/2007
# 9      Routine non-contrast examination of the brain.                None
# 10     Routine non-contrast examination of the brain.           12/2/2007
# 11  3-mm reconstructed sections are obtained from ...                None
# 12  4-mm reconstructed sections are obtained from ...                None
# 13  2-mm reconstructed sections were obtained from...            12/23/07
# 14                 Routine pulmonary embolus protocol                None
# 15  Routine pulmonary embolus protocol was perform...                None
# 16  Routine gonadal is protocol was performed util...             3/16/06
# 17  4-mm reconstructed sections were obtained from...            12/02/07
# 18                                                NaN             12/7/03
# 19  The 4-mm reconstructed sections were obtained ...            12/25/07
# 20  Routine pulmonary embolus protocol utilized th...                None
# 21  4-mm reconstructed sections were obtained from...                None
# 22  4-mm reconstructed sections are obtained from ...                None
# 23  4-mm reconstructed sections are obtained from ...            10/27/07
# 24  4-mm reconstructed sections are obtained from ...            12/21/07
# 25  3-mm reconstructed sections are obtained from ...                None
# 26     Routine non-contrast examination of the brain.     None available.
# 27     Routine non-contrast examination of the brain.            7/9/2003
# 28     Routine non-contrast examination of the brain.          10/13/2004
# 29     Routine non-contrast examination of the brain.     None available.
#
#                                              FINDINGS  \
# 0   There is mucosal thickening involving the sphe...
# 1   There is evidence of periventricular hypodensi...
# 2   There is no evidence of intracranial hemorrhag...
# 3   Noncontrast CT scan brain is normal. There is ...
# 4   The examination demonstrates mild periventricu...
# 5   Since the previous examination a right frontal...
# 6   Right frontal shunt catheter is again noted wi...
# 7   There is no evidence of intracranial hemorrhag...
# 8   There is no evidence of intracranial hemorrhag...
# 9   There is no evidence of intracranial hemorrhag...
# 10  There is no evidence of intracranial hemorrhag...
# 11  ABDOMEN:LUNG BASES: No significant abnormality...
# 12  ABDOMEN:LUNG BASES: No significant abnormality...
# 13  ABDOMEN:LUNG BASES: A increasing bilateral ple...
# 14  LUNGS AND PLEURA: No evidence acute suggest a ...
# 15  LUNGS AND PLEURA: No evidence to suggest pulmo...
# 16  LUNGS AND PLEURA: No evidence to suggest a pul...
# 17  ABDOMEN:LUNG BASES: No significant abnormality...
# 18  LUNGS AND PLEURA: No evidence to suggest pulmo...
# 19  ABDOMEN:LUNG BASES: Enlarging effusions with i...
# 20  LUNGS AND PLEURA: No evidence of a pulmonary e...
# 21  ABDOMEN:LUNG BASES: No significant abnormality...
# 22  ABDOMEN:LUNG BASES: Bilateral pleural effusion...
# 23  ABDOMEN:LUNG BASES: No significant abnormality...
# 24  ABDOMEN:LUNG BASES: No significant change in l...
# 25  ABDOMEN:LUNG BASES: Minimal patchy peripheral ...
# 26  There is no evidence of intracranial hemorrhag...
# 27  Patchy areas of hypoattenuation in the parieta...
# 28  There is no evidence of intracranial hemorrhag...
# 29  There is no evidence of intracranial hemorrhag...
#
#                                  CLINICAL INFORMATION
# 0   History of right periorbital cellulitis diagno...
# 1   Patient with left-sided weakness and the plaqu...
# 2   One month old with history of fall. No loss of...
# 3                                            Headache
# 4   82-year-old with fever and mental status chang...
# 5                                 Status post surgery
# 6                               Check shunt placement
# 7   rule out CVA in 63 are old woman with altered ...
# 8   Rule out stroke or bleed in patient with slurr...
# 9   51 year old with aortic aneurysm repair now wi...
# 10  Status post blunt head trauma with head lacera...
# 11  22 year-old female with upper quadrant pain an...
# 12  33-year-old male with bilateral lower quadrant...
# 13  86-year-old female post endovascular aortic re...
# 14  PE protocol, head trauma now with tachypnea an...
# 15  Patient with respiratory distress rule out PE....
# 16  Status post lung transplant now with shortness...
# 17  38-year-old male with history of Berger proced...
# 18  Sickle cell disease history of DVT in the past...
# 19  69-year-old male with prostate carcinoma post ...
# 20  Sudden onset of pleuritic chest pain. Fever ta...
# 21  37-year-old male with history pancreatitis, no...
# 22  67-year-old female with AML and neutropenia, n...
# 23  39-year-old male post laparoscopic cholecystec...
# 24  68-year-old male with decreasing hemoglobin. P...
# 25  78-year-old male with history of BPH admitted ...
# 26  Patient is a 59-year-old female with history o...
# 27  71-year-old female with diabetes hypertension ...
# 28  The patient is a 73-year-old female with alter...
# 29  The patient is a 21-year-old female with acute...

# %%
#Drop rows where length of IMPRESSION exceeds the required MIN_LEN
MIN_LEN = 120
data_df = data_df.drop(data_df[data_df['IMPRESSION'].map(len) > MIN_LEN].index)

# %% [markdown]
# Data Conversion

# %%
# %%time
res = convert_data_to_jsonl(data_df)
# Out:
# CPU times: user 8min 2s, sys: 2.24 s, total: 8min 4s
# Wall time: 8min 4s

# %%
dump(res, 'ia_data_all_u.jsonl')

# %% [markdown]
# Train Test Split

# %%
train, dev, test = train_test_split(res, train_ratio=0.80, dev_ratio=0.10, test_ratio=0.10)

# %%
dump(train, './dataset/ia-patients/trainu.jsonl')
dump(dev, './dataset/ia-patients/devu.jsonl')
dump(test, './dataset/ia-patients/testu.jsonl')

# %% [markdown]
# ### Following is self optionals trials of Utku

# %%
import json
import uuid
from IPython.display import display_javascript, display_html, display
#import plotly.plotly as py
#import base64
#import plotly.graph_objs as go

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
            self.uuid = str(uuid.uuid4())

    def _ipython_display_(self):
        display_html('<div id="{}" style="height: 600px; width:100%;"></div>'.format(self.uuid), raw=True)
        display_javascript("""
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
        document.getElementById('%s').appendChild(renderjson(%s))
        });
        """ % (self.uuid, self.json_str), raw=True)

# %%
list_of_json_files = []
for line in open('./dataset/ia-patients/testu.jsonl', 'r'):
    tweets.append(json.loads(line))


#with open('ia_data_all_u.jsonl') as json_file:  
 #   data = json.load(json_file)
#a=json.loads()

#json.loads(x)

#RenderJSON(json.dumps(data))
len(list_of_json_files)
# Out:
# 18660

# %% [markdown]
# # Test ground

# %%
nltk.word_tokenize("Hey, I feel didn't bad utku")
